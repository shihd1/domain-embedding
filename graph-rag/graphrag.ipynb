# %%
# %pip install graphrag
# Out:
# ...
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# ...
#      ---------------------------------------- 0.0/79.4 kB ? eta -:--:--
#      --------------- ------------------------ 30.7/79.4 kB 1.3 MB/s eta 0:00:01
#      ------------------- ------------------ 41.0/79.4 kB 487.6 kB/s eta 0:00:01
#      -------------------------------------- 79.4/79.4 kB 736.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#      ---- ----------------------------------- 0.1/1.2 MB 3.6 MB/s eta 0:00:01
#      ---- ----------------------------------- 0.1/1.2 MB 2.0 MB/s eta 0:00:01
#      -------- ------------------------------- 0.3/1.2 MB 2.3 MB/s eta 0:00:01
#      ------------ --------------------------- 0.4/1.2 MB 2.1 MB/s eta 0:00:01
# ...

# %%
# !python -m graphrag.index --init --root .
# Out:
# ⠋ GraphRAG Indexer
# Initializing project at .
# ⠋ GraphRAG Indexer
# Traceback (most recent call last):
# ⠋ GraphRAG Indexer
#   File "<frozen runpy>", line 198, in _run_module_as_main
# ⠋ GraphRAG Indexer
#   File "<frozen runpy>", line 88, in _run_code
# ⠋ GraphRAG Indexer
#   File
# "c:\Users\clkds12\AppData\Local\anaconda3\Lib\site-packages\graphrag\index\__ma
# in__.py", line 68, in <module>
# ⠋ GraphRAG Indexer
#     index_cli(
# ⠋ GraphRAG Indexer
#   File
# "c:\Users\clkds12\AppData\Local\anaconda3\Lib\site-packages\graphrag\index\cli.
# py", line 90, in index_cli
# ⠋ GraphRAG Indexer
#     _initialize_project_at(root, progress_reporter)
# ⠋ GraphRAG Indexer
#   File
# "c:\Users\clkds12\AppData\Local\anaconda3\Lib\site-packages\graphrag\index\cli.
# py", line 179, in _initialize_project_at
# ⠋ GraphRAG Indexer
#     raise ValueError(msg)
# ⠋ GraphRAG Indexer
# ValueError: Project already initialized at .
# ⠋ GraphRAG Indexer

# %%
# !python -m graphrag.index --root .
# Out:
# ^C
